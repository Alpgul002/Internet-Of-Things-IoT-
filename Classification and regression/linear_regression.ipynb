# %% [markdown]
# # Regression Visualization

# %% [markdown]
# Example from https://github.com/slavastar/ML-medium/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File ~/Dev/SU/Lectures/ML/Classification/venv/lib/python3.14/site-packages/pandas/__init__.py:14
#      12 for _dependency in _hard_dependencies:
#      13     try:
# ---> 14         __import__(_dependency)
#      15     except ImportError as _e:  # pragma: no cover
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/Dev/SU/Lectures/ML/Classification/venv/lib/python3.14/site-packages/numpy/__init__.py:852
#     849         pass
#     851 if sys.platform == "darwin":
# --> 852     from . import exceptions
#     853     with warnings.catch_warnings(record=True) as w:
#     854         _mac_os_check()
#
# File <frozen importlib._bootstrap>:1423, in _handle_fromlist(module, fromlist, import_, recursive)
#    1420     if not recursive and hasattr(module, '__all__'):
#    1421         _handle_fromlist(module, module.__all__, import_,
#    1422                          recursive=True)
# -> 1423 elif not hasattr(module, x):
#    1424     from_name = f'{module.__name__}.{x}'
#    1425     try:
#
# File ~/Dev/SU/Lectures/ML/Classification/venv/lib/python3.14/site-packages/numpy/__init__.py:733, in __getattr__(attr)
#     731     return ctypeslib
#     732 elif attr == "exceptions":
# --> 733     import numpy.exceptions as exceptions
#     734     return exceptions
#     735 elif attr == "testing":
#
# File ~/Dev/SU/Lectures/ML/Classification/venv/lib/python3.14/site-packages/numpy/__init__.py:733, in __getattr__(attr)
#     731     return ctypeslib
#     732 elif attr == "exceptions":
# --> 733     import numpy.exceptions as exceptions
#     734     return exceptions
#     735 elif attr == "testing":
#
#     [... skipping similar frames: __getattr__ at line 733 (1674 times)]
#
# File ~/Dev/SU/Lectures/ML/Classification/venv/lib/python3.14/site-packages/numpy/__init__.py:733, in __getattr__(attr)
#     731     return ctypeslib
#     732 elif attr == "exceptions":
# --> 733     import numpy.exceptions as exceptions
#     734     return exceptions
#     735 elif attr == "testing":
#
# File <frozen importlib._bootstrap>:472, in _lock_unlock_module(name)
#     466 def _lock_unlock_module(name):
#     467     """Acquires then releases the module lock for a given module name.
#     468
#     469     This is used to ensure a module is completely initialized, in the
#     470     event it is being imported by another thread.
#     471     """
# --> 472     lock = _get_module_lock(name)
#     473     try:
#     474         lock.acquire()
#
# File <frozen importlib._bootstrap>:435, in _get_module_lock(name)
#     429 def _get_module_lock(name):
#     430     """Get or create the module lock for a given module name.
#     431
#     432     Acquire/release internally the global import lock to protect
#     433     _module_locks."""
# --> 435     _imp.acquire_lock()
#     436     try:
#     437         try:
#
# RecursionError: Stack overflow (used 3906 kB) while calling a Python object

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data
# In this example, we are going to use a dataset with one feature *x* and target *y* that we need to predict.

# %%
data = [
    (6, 6),
    (0, 3),
    (4, 5),
    (-1, -3),
    (2, 0),
    (6, 7),
    (4, 4),
    (-4, -1),
    (-3, 5),
    (2, 0)
]
data = pd.DataFrame(data, columns=['x', 'y'])
data
# Out:
#    x  y
# 0  6  6
# 1  0  3
# 2  4  5
# 3 -1 -3
# 4  2  0
# 5  6  7
# 6  4  4
# 7 -4 -1
# 8 -3  5
# 9  2  0

# %% [markdown]
# Let us visualise the dataset:

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=data, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# # Gradient Descent
# We will implement the batch gradient descent. For the loss function we are going to use MSE.

# %%
def mse(y_true: pd.Series, y_pred: pd.Series) -> float:
    return ((y_true - y_pred) ** 2).sum() / len(y_pred)

# %% [markdown]
# In the cell below we declare parameters of the algorithm.
# * *Iterations* specify how many times we are going to update weights. In most cases, the higher the number of iterations is, the more precisely the algorithm converges.
# * *Learning rate* (usually denoted as *alpha*) influences the scale of each update. Usually, with lower values of alpha, the algorithm converges more precisely but it takes more time for training. However, by choosing a very large value for the rate, the algorithm can highly jump over the local minima. As a result, the algorithm will not converge correctly.
# * *Batch size* allows to use several objects on each iteration for weights update. If we choose batch size to be equal to 1, then gradient descent is called stochastic.
# * *w* and *b* are initial values of weights. There exist several strategies for their initialization. In the example, we are going to assign small random values to them.

# %%
iterations = 1000
batch_size = 5
alpha = 0.001
w, b = np.random.rand(2)

# %%
# this dictionary will be used for tracking parameters of each iteration
history = {
    'iteration': [],
    'w': [],
    'b': [],
    'loss': []
}

# %%
for iteration in range(iterations):

    # choosing object in batch
    batch_indices = np.random.randint(0, len(data), batch_size)
    batch_data = data.loc[batch_indices]

    x, y, n = batch_data['x'], batch_data['y'], len(batch_data)
    y_hat = w * batch_data['x'] + b # prediction

    # weights update
    w -= alpha * 2 / n * (x * (y_hat - y)).sum()
    b -= alpha * 2 / n * (y_hat - y).sum()

    loss = mse(data['y'], w * data['x'] + b) # total loss

    # saving parameters on current iteration
    history['iteration'].append(iteration)
    history['w'].append(w)
    history['b'].append(b)
    history['loss'].append(loss)

# %% [markdown]
# # Analysis of parameters
# Let us draw several plots of parameters that we tracked throughout the training process.

# %%
plt.figure(figsize=(12, 9))
sns.lineplot(x=history['iteration'], y=history['b'], color='red', label='b')
sns.lineplot(x=history['iteration'], y=history['w'], color='orange', label='w')
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.title('Weights on each iteration')
# Out:
# Text(0.5, 1.0, 'Weights on each iteration')

# %%
plt.figure(figsize=(12, 9))
sns.lineplot(x=history['iteration'], y=history['loss'], color='red')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss value on each iteration')
# Out:
# Text(0.5, 1.0, 'Loss value on each iteration')

# %% [markdown]
# During the training process, the loss value should normally decrease with each iteration.

# %%
print(f'Linear regression equation: y = {w:.3f} * x + {b:.3f}')
print(f'Total loss: {loss:.3f}')
# Out:
# Linear regression equation: y = 0.622 * x + 1.425
# Total loss: 6.610

# %% [markdown]
# # Regression line
# Since we have trained a model on a dataset with only one feature, it is easy to visualise the results in the form of a regression line on 2D-plane. If we had more than 2 features, then it would have been problematic.
#
# The closer the line fits to all of the points, the better our model is.

# %%
regression_line = pd.DataFrame(
    data=[(x, w * x + b) for x in np.linspace(data.min().min(), data.max().max(), 500)],
    columns=['x', 'y']
)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=data, x='x', y='y')
sns.scatterplot(data=regression_line, x='x', y='y', marker='x', color='orange')
plt.title('Fitting line of linear regression')
# Out:
# Text(0.5, 1.0, 'Fitting line of linear regression')
